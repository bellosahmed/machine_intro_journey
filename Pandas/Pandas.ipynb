# %%
print(" Hello World") # Works normal like python
# Out:
#  Hello World

# %%
import pandas as pd # just to import the file

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"]) #pd.Series is like putting object in a list to call them out

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
# 2 main datatypes
colors = pd.Series(["Red", "Blue", "Yellow"]) 
colors
# Out:
# 0       Red
# 1      Blue
# 2    Yellow
# dtype: object

# %%
# dataframe = 2-dimensional
car_data = pd.DataFrame({"Car make": series, "Color": colors}) # calling out colors and series we listed earlier
car_data
# Out:
#   Car make   Color
# 0      BMW     Red
# 1   Toyota    Blue
# 2    Honda  Yellow

# %%
# Import data
car_sales = pd.read_csv("data/car-sales.csv") # pd.read_csv - this is to import the data we have in our folder note: folder location and file name must match
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting data
car_sales.to_csv("data/exported-car-sales.csv", index=False) # this is to export the file and when we call index= false it removed some data we dont want

# %%
exported_car_sales = pd.read_csv("data/exported-car-sales.csv") # this is to import the file
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# car_sales.mean(numeric_only=True) will work not  car_sales.mean()

# %% [markdown]
# ## Describe data

# %%
# Attributes
car_sales.dtypes # attribute dont have () while function have it but depends on how you call them

# Function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns # .coloumns to list the data we have in columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns # just making it easier to call
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index #
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe # .describe to describe the data we have
# Out:
# <bound method NDFrame.describe of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
car_sales.info() # .info to get some specific information we need in the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True) # to get the mean but you must put numeric_only = true because .mean does not work like before
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([300, 1500, 111250]) # just listing the data we have in series
car_prices.mean(numeric_only=True) # getting the mean of the data above
# Out:
# np.float64(37683.333333333336)

# %%
car_sales.sum() # .sum is the total sum thats is called out
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum() # total sums of doors we have
# Out:
# np.int64(40)

# %%
len(car_sales) # len  is lenght of it but starts from 0 to 1
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head(3) # gives the top part of the data
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.tail(2) # gives the bottom part of the data
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc and .iloc
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"], index=[0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# refrs to the index
animals.loc[9] # by number called
# Out:
# 'bird'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[0] # nb by index
# Out:
# Make                Toyota
# Colour               White
# Odometer (KM)       150043
# Doors                    4
# Price            $4,000.00
# Name: 0, dtype: object

# %%
# .iloc refers to the postion
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[1]
# Out:
# Make                 Honda
# Colour                 Red
# Odometer (KM)        87899
# Doors                    4
# Price            $5,000.00
# Name: 1, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3] # same with .head
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
#regex=True eg car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True)

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"]) # we called out doors and make
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# groupby
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Import matplotlib and tell Jupyter to show plots
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
car_sales.plot(x="Make", y="Odometer (KM)");

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: xlabel='Make'>

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 car_sales["Price"].plot()
#
# File c:\Users\bello\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\bello\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\bello\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:499, in MPLPlot.generate(self)
#     497 @final
# ...

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$,]', '', regex=True).astype(float).astype('Int64')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulation Data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Make"] = car_sales["Make"].str.lower() # to make all strings lower in the make

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv("data/car-sales-missing-data.csv") # import the data
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean(numeric_only=False) # getting the mean
# Out:
# np.float64(92302.66666666667)

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(numeric_only=False))  # filling all the data in na missing value
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing # but not all was filled
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Fill the Odometer missing values to the mean with inplace=True
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(numeric_only=False)) # created value of odometer to fill the missing value of na

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing.dropna() # dropping or removing missing values
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True) # by putting true change made forever

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("data/car-sales-missing-data.csv") # import the data
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna() # defined new function
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("data/car-sales-missing-dropped.csv")

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
# Column from Series
seats_column = pd.Series([5, 5, 5, 5, 5,])

# New column called seats
car_sales["Seats"] = seats_column
seats_column # adding data column to car sales
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    NaN
# 6   honda   Blue          45698      4   7500    NaN
# 7   honda   Blue          54738      4   7000    NaN
# 8  toyota  White          60000      4   6250    NaN
# 9  nissan  White          31600      4   9700    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True) # filling all na in seats to be 5
car_sales
# Out:
# C:\Users\bello\AppData\Local\Temp\ipykernel_34136\2575828071.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales["Seats"].fillna(5, inplace=True) # filling all na in seats to be 5
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# ...

# %%
# Column from puthon list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4,7, 7.6, 8.7, 3.0] # adding new column
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.0
# 6   honda   Blue          45698      4   7500    5.0             7.0
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             3.0

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"] /100 * car_sales["Fuel per 100KM"] ## to get fuel used km/100 * fuel
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.0
# 6   honda   Blue          45698      4   7500    5.0             7.0
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             3.0
#
#    Total fuel used (L)
# 0            11253.225
# 1             8086.708
# 2             1627.450
# 3             1073.184
# 4            18539.265
# 5             3968.520
# 6             3198.860
# ...

# %%
# Create a column from a single valuw
car_sales["Number of wheels"] = 4
car_sales ## adding wheels
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.0
# 6   honda   Blue          45698      4   7500    5.0             7.0
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             3.0
#
#    Total fuel used (L)  Number of wheels
# 0            11253.225                 4
# 1             8086.708                 4
# 2             1627.450                 4
# ...

# %%
car_sales["Passed road satefy"] = True
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                    Int64
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used (L)    float64
# Number of wheels         int64
# Passed road satefy        bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.0
# 6   honda   Blue          45698      4   7500    5.0             7.0
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             3.0
#
#    Total fuel used (L)  Number of wheels  Passed road satefy
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
# Drop the Price per KM column
car_sales = car_sales.drop("Total fuel used (L)", axis=1) # columns live on axis 1
car_sales # dropping the data L but most called axis=1
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.0
# 6   honda   Blue          45698      4   7500    5.0             7.0
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             3.0
#
#    Number of wheels  Passed road satefy
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.0
# 6   honda   Blue          45698      4   7500    5.0             7.0
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             3.0
#
#    Number of wheels  Passed road satefy
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1) # 1 is 100 get the sample but randomly

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 6   honda   Blue          45698      4   7500    5.0             7.0
# 5  toyota  Green          99213      4   4500    5.0             4.0
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 0  toyota  White         150043      4   4000    5.0             7.5
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 9  nissan  White          31600      4   9700    5.0             3.0
# 4  nissan  White         213095      4   3500    5.0             8.7
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 1   honda    Red          87899      4   5000    5.0             9.2
# 8  toyota  White          60000      4   6250    5.0             8.7
#
#    Number of wheels  Passed road satefy
# 6                 4                True
# 5                 4                True
# 2                 4                True
# 0                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.0
# 6   honda   Blue          45698      4   7500    5.0             7.0
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             3.0
#
#    Number of wheels  Passed road satefy
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# ...

# %%
# only for 20 percent of the data
car_sales_shuffled.sample(frac=0.20)
# Out:
#     Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 1  honda    Red          87899      4   5000    5.0             9.2
# 6  honda   Blue          45698      4   7500    5.0             7.0
#
#    Number of wheels  Passed road satefy
# 1                 4                True
# 6                 4                True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True) # reset the data

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0   honda   Blue          45698      4   7500    5.0             7.0
# 1  toyota  Green          99213      4   4500    5.0             4.0
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3  toyota  White         150043      4   4000    5.0             7.5
# 4   honda   Blue          54738      4   7000    5.0             7.6
# 5  nissan  White          31600      4   9700    5.0             3.0
# 6  nissan  White         213095      4   3500    5.0             8.7
# 7     bmw  Black          11179      5  22000    5.0             9.6
# 8   honda    Red          87899      4   5000    5.0             9.2
# 9  toyota  White          60000      4   6250    5.0             8.7
#
#    Number of wheels  Passed road satefy
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x:x/1.6) # conversion from km to miles
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   4000    5.0             7.5
# 1   honda    Red      54936.875      4   5000    5.0             9.2
# 2  toyota   Blue      20343.125      3   7000    5.0             5.0
# 3     bmw  Black       6986.875      5  22000    5.0             9.6
# 4  nissan  White     133184.375      4   3500    5.0             8.7
# 5  toyota  Green      62008.125      4   4500    5.0             4.0
# 6   honda   Blue      28561.250      4   7500    5.0             7.0
# 7   honda   Blue      34211.250      4   7000    5.0             7.6
# 8  toyota  White      37500.000      4   6250    5.0             8.7
# 9  nissan  White      19750.000      4   9700    5.0             3.0
#
#    Number of wheels  Passed road satefy
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# ...
