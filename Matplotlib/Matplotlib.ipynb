# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Create a simple plot, without the semi-colon
plt.plot()
plt.show()

# %%
plt.plot();
plt.show();

# %%
# Let's add some data
plt.plot([1, 2, 3, 4]);
plt.show()

# %%
# Create some data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);
plt.show()

# %%
# Creating a plot with the object-orientated verison
# 1 method
fig = plt.figure() # create a figure
ax = fig.add_subplot() # add an axes 
plt.show()

# %%
# 2 method
fig = plt.figure() # create a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
# 3 way best
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 350])
plt.show()

# %% [markdown]
# # Anatomy of a Matplotlib Figure

# %% [markdown]
# The following workflow is a standard practice when creating a matplotlib plot:
#
# 0. Import matplotlib - For example, import matplotlib.pyplot as plt).
# 1. Prepare data - This may be from an existing dataset (data analysis) or from the outputs of a machine learning model (data science).
# 2. Setup the plot - In other words, create the Figure and various Axes.
# 3. Plot data to the Axes - Send the relevant data to the target Axes.
# 4. Cutomize the plot - Add a title, decorate the colours, label each Axis.
# 5. Save (optional) and show - See what your masterpiece looks like and save it to file if necessary.

# %%
# A matplotlib workflow

# 0. Import and get matplotlib ready
# %matplotlib inline # Not necessary in newer versions of Jupyter (e.g. 2022 onwards)
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot (Figure and Axes)
fig, ax = plt.subplots(figsize=(10,10))

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Sample Simple Plot", 
       xlabel="x-axis", 
       ylabel="y-axis")

# 5. Save & show
fig.savefig("img/simple-plot.png")
plt.show();

# %%
import numpy as np

# %%
# create data
x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
# plot the data
fig, ax = plt.subplots()
ax.plot(x, x**2)
plt.show()

# %% [markdown]
# Most of figuring out what kind of plot to use is getting a feel for the data, then seeing what kind of plot suits it best.
#
# Matplotlib visualizations are built on NumPy arrays. So in this section we'll build some of the most common types of plots using NumPy arrays.
#
# * Line plot - ax.plot() (this is the default plot in matplotlib)
# * Scatter plot - ax.scatter()
# * Bar plot - ax.bar()
# * Histogram plot - ax.hist()

# %%
# make scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));
plt.show()

# %%
# another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));
plt.show()

# %%
# You can make plots from a dictionary and also bar
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Dan's Nut Butter Store", ylabel="Price ($)");
plt.show();

# %%
fig, ax= plt.subplots()
ax.barh(list(nut_butter_prices.keys()),
              list(nut_butter_prices.values()));
plt.show();

# %%
## Histogram
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x)
plt.show();

# %%
# Two option of subplots

# %%
# option one of subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, 
                                             ncols=2, 
                                             figsize=(10, 5))
# Plot data to each axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));
plt.show();

# %%
# Option 2: Create 4 subplots with a single ax variable
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

# Index the ax variable to plot data
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));
plt.show();

# %% [markdown]
# ## Plotting from pandas dataframes

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("data/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Start with some dummy data
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2025', periods=1000))

# Note: ts = short for time series (data over time)
ts

ts.plot()
plt.show();

# %%
# Add up the values cumulatively
ts.cumsum()
# Out:
# 2025-01-01    -0.861451
# 2025-01-02    -1.123777
# 2025-01-03     0.091235
# 2025-01-04     0.872300
# 2025-01-05    -0.086884
#                 ...
# 2027-09-23     9.498422
# 2027-09-24    10.646276
# 2027-09-25    11.090690
# 2027-09-26    10.474812
# 2027-09-27     9.598706
# Freq: D, Length: 1000, dtype: float64

# %%
# remove dollar sign
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
# remove the two extra zero
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2025", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2025-01-01
# 1   Honda    Red          87899      4   5000 2025-01-02
# 2  Toyota   Blue          32549      3   7000 2025-01-03
# 3     BMW  Black          11179      5  22000 2025-01-04
# 4  Nissan  White         213095      4   3500 2025-01-05
# 5  Toyota  Green          99213      4   4500 2025-01-06
# 6   Honda   Blue          45698      4   7500 2025-01-07
# 7   Honda   Blue          54738      4   7000 2025-01-08
# 8  Toyota  White          60000      4   6250 2025-01-09
# 9  Nissan  White          31600      4   9700 2025-01-10

# %%
# Make total sales column (doesn't work, adds as string)
#car_sales["Total Sales"] = car_sales["Price"].cumsum()

# Oops... want them as int's not string
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500
# 5  Toyota  Green          99213      4   4500 2025-01-06        46000
# 6   Honda   Blue          45698      4   7500 2025-01-07        53500
# 7   Honda   Blue          54738      4   7000 2025-01-08        60500
# 8  Toyota  White          60000      4   6250 2025-01-09        66750
# 9  Nissan  White          31600      4   9700 2025-01-10        76450

# %%
car_sales.plot(x='Sale Date', y='Total Sales');
plt.show()

# %%
car_sales["Price"] = car_sales["Price"].astype(str)

# Plot a scatter plot
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");
plt.show();

# %%
# Create 10 random samples across 4 columns
x = np.random.rand(10, 4)
x
# Out:
# array([[0.87988519, 0.17175149, 0.7310141 , 0.79245029],
#        [0.81646315, 0.21248201, 0.75382602, 0.5491038 ],
#        [0.98265728, 0.19400063, 0.42862979, 0.29263057],
#        [0.9200042 , 0.89268454, 0.16934155, 0.10785029],
#        [0.55983512, 0.53873097, 0.49621372, 0.68039824],
#        [0.41592446, 0.5091623 , 0.505553  , 0.60364572],
#        [0.79221218, 0.48359144, 0.81036894, 0.94318249],
#        [0.04110098, 0.35295834, 0.66527584, 0.91182801],
#        [0.79776221, 0.07944735, 0.00528843, 0.98692108],
#        [0.80357746, 0.71601825, 0.90300454, 0.99122165]])

# %%
# Turn the data into a DataFrame
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.879885  0.171751  0.731014  0.792450
# 1  0.816463  0.212482  0.753826  0.549104
# 2  0.982657  0.194001  0.428630  0.292631
# 3  0.920004  0.892685  0.169342  0.107850
# 4  0.559835  0.538731  0.496214  0.680398
# 5  0.415924  0.509162  0.505553  0.603646
# 6  0.792212  0.483591  0.810369  0.943182
# 7  0.041101  0.352958  0.665276  0.911828
# 8  0.797762  0.079447  0.005288  0.986921
# 9  0.803577  0.716018  0.903005  0.991222

# %%
# Plot a bar chart
df.plot.bar();
plt.show();

# %%
# Plot a bar chart with the kind parameter
df.plot(kind='bar');
plt.show();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500
# 5  Toyota  Green          99213      4   4500 2025-01-06        46000
# 6   Honda   Blue          45698      4   7500 2025-01-07        53500
# 7   Honda   Blue          54738      4   7000 2025-01-08        60500
# 8  Toyota  White          60000      4   6250 2025-01-09        66750
# 9  Nissan  White          31600      4   9700 2025-01-10        76450

# %%
# Plot a bar chart from car_sales DataFrame
car_sales.plot(x="Make", 
               y="Odometer (KM)", 
               kind="bar");
plt.show();

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10); # default number of bins (or groups) is 10
plt.show()

# %%
car_sales["Odometer (KM)"].plot(kind="hist");
plt.show()

# %%
# Default number of bins is 10 
car_sales["Odometer (KM)"].plot.hist(bins=20);
plt.show();

# %%
# Create a histogram of the Price column
# car_sales["Price"].plot.hist(bins=10);

# %% [markdown]
# ## Heart Diease

# %%
heart_disease = pd.read_csv("data/heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
# create a histogram of age
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
heart_disease.plot.hist(figsize=(10,30), subplots=True);

# %% [markdown]
# ### pyplot vs matplotlib oo method
#
# * Fast use pyplot
# * more advance matplotlib

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             );

# %%
## oo method
fix, ax = plt.subplots(figsize = (10, 6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
            ax=ax); # set the target Axes

# Customize the x-axis limits (to be within our target age ranges)
ax.set_xlim([45, 100]);

# %%
# using oo method
# Create Figure and Axes instance
fig, ax = plt.subplots(figsize=(10, 6))

# Plot data directly to the Axes intance
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"]) # Colour the data with the "target" column

# Customize the plot parameters 
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Setup the legend
ax.legend(*scatter.legend_elements(), 
          title="Target");

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Add a legned
ax.legend(*scatter.legend_elements(), 
          title="Target")

# Add a meanline or horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle="--"); # style the line to make it look nice

# %%
# Setup plot (2 rows, 1 column)
fig, (ax0, ax1) = plt.subplots(nrows=2, # 2 rows
                               ncols=1, # 1 column 
                               sharex=True, # both plots should use the same x-axis 
                               figsize=(10, 8))

# ---------- Axis 0: Heart Disease and Cholesterol Levels ----------

# Add data for ax0
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"])
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# ---------- Axis 1: Heart Disease and Max Heart Rate Levels ----------

# Add data for ax1
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"])

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# Title the figure
fig.suptitle('Heart Disease Analysis', 
             fontsize=16, 
             fontweight='bold');

# %%
## Customize our plot

# %%
# Check the available styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500
# 5  Toyota  Green          99213      4   4500 2025-01-06        46000
# 6   Honda   Blue          45698      4   7500 2025-01-07        53500
# 7   Honda   Blue          54738      4   7000 2025-01-08        60500
# 8  Toyota  White          60000      4   6250 2025-01-09        66750
# 9  Nissan  White          31600      4   9700 2025-01-10        76450

# %%
car_sales.plot(x="Odometer (KM)", 
               y="Price", 
               kind="scatter");

# %%
# Change the plot style back to the default 
plt.style.use("default")

# %%
# Create random data
x = np.random.randn(10, 4)
x
# Out:
# array([[ 1.82028489, -1.40118688, -1.26191457, -0.08618722],
#        [-0.19177416, -1.23292739,  0.33973454, -0.30000602],
#        [-0.18450949,  0.04821926, -0.05073388, -1.70251481],
#        [-0.1478806 ,  0.40307548, -0.58744657, -0.36043859],
#        [-1.18450553,  0.87772683,  0.73926402, -0.97208496],
#        [-2.4457717 ,  1.10499247,  1.11208889,  0.55452564],
#        [-0.40556796,  2.0101511 ,  0.28793025,  0.72395835],
#        [ 0.24888971, -0.25918678,  0.67165593, -0.10229849],
#        [-1.90298549,  0.79719301, -0.9436111 , -0.70672691],
#        [-1.50794698, -1.06573262,  0.89376552,  0.55802932]])

# %%
# Turn data into DataFrame with simple column names
df = pd.DataFrame(x, 
                  columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  1.820285 -1.401187 -1.261915 -0.086187
# 1 -0.191774 -1.232927  0.339735 -0.300006
# 2 -0.184509  0.048219 -0.050734 -1.702515
# 3 -0.147881  0.403075 -0.587447 -0.360439
# 4 -1.184506  0.877727  0.739264 -0.972085
# 5 -2.445772  1.104992  1.112089  0.554526
# 6 -0.405568  2.010151  0.287930  0.723958
# 7  0.248890 -0.259187  0.671656 -0.102298
# 8 -1.902985  0.797193 -0.943611 -0.706727
# 9 -1.507947 -1.065733  0.893766  0.558029

# %%
# Create a bar plot
ax = df.plot(kind="bar")

# Check the type of the ax variable
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
# Recreate the ax object
ax = df.plot(kind="bar")

# Set various attributes
ax.set(title="Random Number Bar Graph from DataFrame", 
       xlabel="Row number", 
       ylabel="Random number");

# %%
# Recreate the ax object
ax = df.plot(kind="bar")

# Set various attributes
ax.set(title="Random Number Bar Graph from DataFrame", 
       xlabel="Row number", 
       ylabel="Random number")

# Change the legend position
ax.legend(loc="upper right");

# %%
# Setup the Figure and Axes
fig, ax = plt.subplots(figsize=(10, 6))

# Create a scatter plot with no cmap change (use default colormap)
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"],
                     cmap="viridis") # default cmap value

# Add attributes to the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");
ax.axhline(y=over_50["chol"].mean(), 
           c='b', 
           linestyle='--', 
           label="Average");
ax.legend(*scatter.legend_elements(), 
          title="Target");

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Setup scatter plot with different cmap
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"], 
                     cmap="winter") # Change color scheme value 

# Add attributes to the plot with different color line
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")
ax.axhline(y=over_50["chol"].mean(), 
           color="r", # Change color of line to "r" (for red)
           linestyle='--', 
           label="Average");
ax.legend(*scatter.legend_elements(), 
          title="Target");

# %%
# Recreate double Axes plot from above with colour updates 
fig, (ax0, ax1) = plt.subplots(nrows=2, 
                               ncols=1, 
                               sharex=True, 
                               figsize=(10, 7))

# ---------- Axis 0 ----------
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap="winter")
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# ---------- Axis 1 ----------
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap="winter")
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax1.legend(*scatter.legend_elements(), 
           title="Target")

# Title the figure
fig.suptitle("Heart Disease Analysis", 
             fontsize=16, 
             fontweight="bold");

# %%
# Recreate the plot from above with custom x and y axis ranges
fig, (ax0, ax1) = plt.subplots(nrows=2, 
                               ncols=1, 
                               sharex=True, 
                               figsize=(10, 7))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol",
        xlim=[50, 80]) # set the x-axis ranges 

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate",
        ylim=[60, 220]) # change the y-axis range

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax1.legend(*scatter.legend_elements(), 
           title="Target")

# Title the figure
fig.suptitle("Heart Disease Analysis", 
             fontsize=16, 
             fontweight="bold");

# %%
# Recreate the plot from above with custom x and y axis ranges
fig, (ax0, ax1) = plt.subplots(nrows=2, 
                               ncols=1, 
                               sharex=True, 
                               figsize=(10, 7))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol",
        xlim=[50, 80]) # set the x-axis ranges 

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate",
        ylim=[60, 220]) # change the y-axis range

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax1.legend(*scatter.legend_elements(), 
           title="Target")

# Title the figure
fig.suptitle("Heart Disease Analysis", 
             fontsize=16, 
             fontweight="bold");

# %%
# Check the supported filetypes
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %%
fig

# %%
# Save the file
fig.savefig(fname="img/heart-disease-analysis.png",
            dpi=100)
